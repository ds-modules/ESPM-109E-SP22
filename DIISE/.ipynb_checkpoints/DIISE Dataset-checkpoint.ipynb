# %%
# Run this cell to set up your notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import folium

# %% [markdown]
# # DIISE Data Set

# %% [markdown]
# ## Rat Eradications

# %% [markdown]
# We get the data set from http://diise.islandconservation.org/ and are interested in seeing the global state of rat eradications. On the website we click "explore" and in the box on the left select "by invasive species" and click "Rodent" for the type of species. Next, click "run search". As we can see, we have data on 837 islands covering 12 species and 1128 eradications. Feel free to explore other species.

# %% [markdown]
# The table that is displayed on the bottom of the screen is the data we will be working with.

# %%
#load the data
rats = pd.read_csv("~/ESPM 109/DIISE_2018_query_new.csv")
pd.options.display.max_columns = None
rats.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 2         6               8  Brown / Norway Rat  Rattus norvegicus
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 2        Rodent                   NaN          Poor                  1988.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 2                1988.0                 Unknown       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 2                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 2                         NaN                Unknown                      NaN
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 2          Unknown                NaN    Broome; Keith
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
#
#               Contact Organization Organization_Website  Island Code  \
# 0                              NaN                  NaN     242232.0
# 1         NZ Dept. of Conservation                  NaN      26860.0
# 2         NZ Dept. of Conservation                  NaN      26852.0
# 3  Galapagos National Park Service                  NaN     362253.0
# 4                              NaN                  NaN     356542.0
#
#         Island Name                      Region         Country  \
# 0       Ailsa Craig      Atlantic Ocean - North  United Kingdom
# 1  Tiritiri Matangi  Pacific Ocean - South West     New Zealand
# 2           Motuihe  Pacific Ocean - South West     New Zealand
# 3      Marielas Sur  Pacific Ocean - North East         Ecuador
# 4             Lobos  Pacific Ocean - North East         Ecuador
#
#          Archipelago         Latitude   Longitude  Area (sq km)  \
# 0   Scotland Islands    55.2520318774   -5.116668      1.005150
# 1       Hauraki Gulf   -36.6008438792  174.890025      2.214972
# 2       Hauraki Gulf    -36.812403102  174.946185      1.823291
# 3  Galapagos Islands  -0.599271767236  -91.090560      0.012435
# 4  Galapagos Islands  -0.856468882571  -89.566197      0.073323
#
#   Human Population
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None

# %% [markdown]
# Look at the table above. What do you notice? What columns stand out to you?

# %% [markdown]
# *Type your answer here.*

# %% [markdown]
# ## About the data:

# %% [markdown]
# Invasive species (such as rats, snakes, rabbits, and cats) are a serious threat to native plants and animals on islands. Islands are currently being threatened by the ongoing climate crisis and eliminating invasive species will help protect island ecosystems and prevent extinctions.

# %% [markdown]
# The Database of Invasive Island Species Eradications collects data on all past and present invasive species eradications on islands. The majority of the data from this database is on invasive mammals. Data points include the specific island, species name, method, and outcome.

# %% [markdown]
# Now, lets dive into the rats table.

# %% [markdown]
# ## Cleaning the data:

# %%
# How many rows and columns are in the rats table?
rats.shape
# Out:
# (1126, 30)

# %% [markdown]
# The shape function is used to find out how many rows and columns are in the data set. The first number represents the number of rows and the last number represents the number of columns. Thus, in the rats dataset, there are 1126 rows and 30 columns.

# %%
# Run this to see all 30 columns in the rats table
rats.columns
# Out:
# Index(['OBJECTID', 'Eradication ID', 'Common Name', 'Scientific Name',
#        'Type (Animal)', 'Year of Introduction', 'Data Quality',
#        'Eradication Start Date', 'Eradication End Date',
#        'Status (Eradication)', 'Type (Eradication)',
#        'Primary Eradication Method', 'Secondary Eradication Method',
#        'Tertiary Eradication Method', 'Primary Baiting Method',
#        'Secondary Baiting Method', 'Primary Toxicant', 'Secondary Toxicant',
#        'Contact Name', 'Contact Organization', 'Organization_Website',
#        'Island Code', 'Island Name', 'Region', 'Country', 'Archipelago',
#        'Latitude', 'Longitude', 'Area (sq km)', 'Human Population'],
#       dtype='object')

# %% [markdown]
# Let's look at the rats table again.

# %%
rats.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 2         6               8  Brown / Norway Rat  Rattus norvegicus
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 2        Rodent                   NaN          Poor                  1988.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 2                1988.0                 Unknown       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 2                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 2                         NaN                Unknown                      NaN
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 2          Unknown                NaN    Broome; Keith
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
#
#               Contact Organization Organization_Website  Island Code  \
# 0                              NaN                  NaN     242232.0
# 1         NZ Dept. of Conservation                  NaN      26860.0
# 2         NZ Dept. of Conservation                  NaN      26852.0
# 3  Galapagos National Park Service                  NaN     362253.0
# 4                              NaN                  NaN     356542.0
#
#         Island Name                      Region         Country  \
# 0       Ailsa Craig      Atlantic Ocean - North  United Kingdom
# 1  Tiritiri Matangi  Pacific Ocean - South West     New Zealand
# 2           Motuihe  Pacific Ocean - South West     New Zealand
# 3      Marielas Sur  Pacific Ocean - North East         Ecuador
# 4             Lobos  Pacific Ocean - North East         Ecuador
#
#          Archipelago         Latitude   Longitude  Area (sq km)  \
# 0   Scotland Islands    55.2520318774   -5.116668      1.005150
# 1       Hauraki Gulf   -36.6008438792  174.890025      2.214972
# 2       Hauraki Gulf    -36.812403102  174.946185      1.823291
# 3  Galapagos Islands  -0.599271767236  -91.090560      0.012435
# 4  Galapagos Islands  -0.856468882571  -89.566197      0.073323
#
#   Human Population
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None

# %% [markdown]
# Notice how the table has 30 columns and many NaN and None values. NaN and None values are put in when certain data is lacking. Look at the "Organization_Website" column. From the first five rows, the website column is all NaN values. However, let's see if there are any real websites in later rows.

# %%
# Find rows that contain an actual website 
rats[~rats['Organization_Website'].isnull()]
# Out:
#       OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 35          53            3206           Black Rat      Rattus rattus
# 43         120             141           Black Rat      Rattus rattus
# 44         121             142           Black Rat      Rattus rattus
# 72         164             205           Black Rat      Rattus rattus
# 110        218             273           Black Rat      Rattus rattus
# ...        ...             ...                 ...                ...
# 1096      2116            3134         House Mouse       Mus musculus
# 1097      2117            3135           Black Rat      Rattus rattus
# 1100      2122            3145  Brown / Norway Rat  Rattus norvegicus
# 1101      2123            3146  Brown / Norway Rat  Rattus norvegicus
# 1103      2125            3149      Polynesian Rat     Rattus exulans
#
#      Type (Animal)  Year of Introduction Data Quality  Eradication Start Date  \
# 35          Rodent                   NaN         Good                  2016.0
# 43          Rodent                   NaN         Good                  2000.0
# 44          Rodent                   NaN         Good                  2000.0
# 72          Rodent                   NaN         Good                  2000.0
# 110         Rodent                   NaN         Good                  2002.0
# ...            ...                   ...          ...                     ...
# 1096        Rodent                   NaN         Good                     NaN
# 1097        Rodent                   NaN         Good                     NaN
# 1100        Rodent                   NaN         Good                  2004.0
# 1101        Rodent                   NaN         Good                  2004.0
# 1103        Rodent                   NaN         Good                  2009.0
#
#       Eradication End Date    Status (Eradication) Type (Eradication)  \
# 35                  2016.0              Successful       Whole Island
# 43                  2000.0  Successful (Reinvaded)       Whole Island
# 44                  2000.0  Successful (Reinvaded)       Whole Island
# 72                  2002.0              Successful       Whole Island
# 110                 2002.0              Successful       Whole Island
# ...                    ...                     ...                ...
# 1096                   NaN                 Planned       Whole Island
# 1097                   NaN                 Planned       Whole Island
# 1100                2004.0  Trial or Research only       Whole Island
# 1101                2004.0  Trial or Research only       Whole Island
# 1103                2009.0  Trial or Research only       Whole Island
#
#      Primary Eradication Method Secondary Eradication Method  \
# 35                     Toxicant                          NaN
# 43                     Toxicant                          NaN
# 44                     Toxicant                          NaN
# 72                     Toxicant                          NaN
# 110                    Toxicant                          NaN
# ...                         ...                          ...
# 1096                   Toxicant                      Unknown
# 1097                    Unknown                      Unknown
# 1100                   Toxicant                          NaN
# 1101                   Toxicant                          NaN
# 1103                   Trapping                          NaN
#
#      Tertiary Eradication Method Primary Baiting Method  \
# 35                           NaN           Bait Station
# 43                           NaN       Aerial Broadcast
# 44                           NaN       Aerial Broadcast
# 72                           NaN           Bait Station
# 110                          NaN           Bait Station
# ...                          ...                    ...
# 1096                     Unknown                Unknown
# 1097                     Unknown                Unknown
# 1100                         NaN           Bait Station
# 1101                         NaN           Bait Station
# 1103                         NaN                    NaN
#
#      Secondary Baiting Method Primary Toxicant Secondary Toxicant  \
# 35                        NaN      Brodifacoum                NaN
# 43                        NaN      Brodifacoum                NaN
# 44                        NaN      Brodifacoum                NaN
# 72                        NaN  Cholecalciferol                NaN
# 110            Hand Broadcast      Brodifacoum                NaN
# ...                       ...              ...                ...
# 1096                  Unknown          Unknown            Unknown
# 1097                  Unknown          Unknown            Unknown
# 1100                      NaN      Diphacinone                NaN
# 1101                      NaN      Diphacinone                NaN
# 1103                      NaN              NaN                NaN
#
#              Contact Name                               Contact Organization  \
# 35           Robinson Sue                                     DIPWE Tasmania
# 43             Merton; D.                           NZ Dept. of Conservation
# 44             Merton; D.                           NZ Dept. of Conservation
# 72     Samaniego; Araceli          Grupo de Ecologia y Conservacion de Islas
# 110        Varnham; Karen  Antiguan Racer Conservation Project; Island Re...
# ...                   ...                                                ...
# 1096  Island Conservation                                Island Conservation
# 1097  Island Conservation                                Island Conservation
# 1100                AMNWR           Alaska Maritime National Wildlife Refuge
# 1101                AMNWR           Alaska Maritime National Wildlife Refuge
# 1103          Pierce; Ray                                Eco Oceania Pty Ltd
#
#                    Organization_Website  Island Code     Island Name  \
# 35           https://dpipwe.tas.gov.au/      26007.0       Big Green
# 43                        pestoff.co.nz      19644.0        Curieuse
# 44                        pestoff.co.nz      19656.0           Denis
# 72                     www.islas.org.mx  110000401.0  San Jorge Este
# 110                         www.irf.org     420441.0   Sandy (White)
# ...                                 ...          ...             ...
# 1096         www.islandconservation.org     356491.0        Floreana
# 1097         www.islandconservation.org     356491.0        Floreana
# 1100      http://alaskamaritime.fws.gov  110000411.0       Channel 1
# 1101      http://alaskamaritime.fws.gov     163703.0       Channel 4
# 1103  http://raypierce.marinenz.org.nz/     357153.0           Orona
#
#                           Region                 Country  \
# 35    Pacific Ocean - South West               Australia
# 43           Indian Ocean - West              Seychelles
# 44           Indian Ocean - West              Seychelles
# 72    Pacific Ocean - North East                  Mexico
# 110                    Caribbean  Virgin Islands British
# ...                          ...                     ...
# 1096  Pacific Ocean - North East                 Ecuador
# 1097  Pacific Ocean - North East                 Ecuador
# 1100  Pacific Ocean - North East           United States
# 1101  Pacific Ocean - North East           United States
# 1103  Pacific Ocean - South East                Kiribati
#
#                                             Archipelago        Latitude  \
# 35                   Tasmanian Islands (Furneaux Group)  -40.1846423716
# 43                                           Seychelles  -4.28282941774
# 44                                           Seychelles  -3.80519850786
# 72                                   Gulf of California   31.0179341243
# 110            Lesser Antilles (British Virgin Islands)   18.4361476811
# ...                                                 ...             ...
# 1096                                  Galapagos Islands  -1.29396397763
# 1097                                  Galapagos Islands  -1.29396397763
# 1100  Aleutian Islands (Adak Island (Bay of Islands-...    51.812732123
# 1101  Aleutian Islands (Adak Island (Bay of Islands-...   51.8111058004
# 1103                                    Phoenix Islands   -4.5215945817
#
#        Longitude  Area (sq km) Human Population
# 35    147.978612      1.227897           1 - 10
# 43     55.725510      2.907248           1 - 10
# 44     55.666978      1.276333       101 - 1000
# 72   -113.248209      0.009906             None
# 110   -64.709412      0.058789             None
# ...          ...           ...              ...
# 1096  -90.435052    172.334280       101 - 1000
# 1097  -90.435052    172.334280       101 - 1000
# 1100 -176.815192      0.004029             None
# 1101 -176.818922      0.003744             None
# 1103 -172.202324      4.627850             None
#
# [206 rows x 30 columns]

# %% [markdown]
# Scroll through this table and notice that all rows have actual websites. In the bottom of the data set you will see that there are 206 rows. This means that out of 1126 total rows in the rats dataset, only 206 of these rows contain actual data. Let's delete this column since only a small percentage of the "Organization_Website" column contains actual data.

# %%
# drop the Organization_Website column
rats = rats.drop('Organization_Website', axis=1)
rats.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 2         6               8  Brown / Norway Rat  Rattus norvegicus
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 2        Rodent                   NaN          Poor                  1988.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 2                1988.0                 Unknown       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 2                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 2                         NaN                Unknown                      NaN
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 2          Unknown                NaN    Broome; Keith
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
#
#               Contact Organization  Island Code       Island Name  \
# 0                              NaN     242232.0       Ailsa Craig
# 1         NZ Dept. of Conservation      26860.0  Tiritiri Matangi
# 2         NZ Dept. of Conservation      26852.0           Motuihe
# 3  Galapagos National Park Service     362253.0      Marielas Sur
# 4                              NaN     356542.0             Lobos
#
#                        Region         Country        Archipelago  \
# 0      Atlantic Ocean - North  United Kingdom   Scotland Islands
# 1  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 2  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 3  Pacific Ocean - North East         Ecuador  Galapagos Islands
# 4  Pacific Ocean - North East         Ecuador  Galapagos Islands
#
#           Latitude   Longitude  Area (sq km) Human Population
# 0    55.2520318774   -5.116668      1.005150             None
# 1   -36.6008438792  174.890025      2.214972             None
# 2    -36.812403102  174.946185      1.823291             None
# 3  -0.599271767236  -91.090560      0.012435             None
# 4  -0.856468882571  -89.566197      0.073323             None

# %% [markdown]
# Let's see if we can drop any other columns. Look at the "Human Population" column. It seems like there are a lot of None values. Let's do the same thing we did with the "Organization_Website" column.

# %%
# Find how many None values are in the "Human Population" column
rats[(rats['Human Population'] != 'None') & (rats['Human Population'] != 'Unknown')]
# Out:
#       OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 5           10              14  Brown / Norway Rat  Rattus norvegicus
# 6           11              15           Black Rat      Rattus rattus
# 7           12              16         House Mouse       Mus musculus
# 35          53            3206           Black Rat      Rattus rattus
# 43         120             141           Black Rat      Rattus rattus
# ...        ...             ...                 ...                ...
# 1118      2152            3212      Polynesian Rat     Rattus exulans
# 1122      2161            3228  Brown / Norway Rat  Rattus norvegicus
# 1123      2162            3229  Brown / Norway Rat  Rattus norvegicus
# 1124      2163            3230  Brown / Norway Rat  Rattus norvegicus
# 1125      2164            3231  Brown / Norway Rat  Rattus norvegicus
#
#      Type (Animal)  Year of Introduction  Data Quality  \
# 5           Rodent                   NaN          Good
# 6           Rodent                   NaN  Satisfactory
# 7           Rodent                   NaN  Satisfactory
# 35          Rodent                   NaN          Good
# 43          Rodent                   NaN          Good
# ...            ...                   ...           ...
# 1118        Rodent                   NaN  Satisfactory
# 1122        Rodent                   NaN  Satisfactory
# 1123        Rodent                   NaN          Poor
# 1124        Rodent                   NaN          Poor
# 1125        Rodent                   NaN  Satisfactory
#
#       Eradication Start Date  Eradication End Date    Status (Eradication)  \
# 5                     1995.0                1996.0                  Failed
# 6                     1994.0                1996.0  Successful (Reinvaded)
# 7                     1994.0                1994.0              Successful
# 35                    2016.0                2016.0              Successful
# 43                    2000.0                2000.0  Successful (Reinvaded)
# ...                      ...                   ...                     ...
# 1118                  1997.0                1997.0                  Failed
# 1122                     NaN                2006.0              Successful
# 1123                     NaN                2009.0              Successful
# 1124                     NaN                   NaN                  Failed
# 1125                     NaN                2016.0             In Progress
#
#       Type (Eradication) Primary Eradication Method  \
# 5           Whole Island                   Toxicant
# 6           Whole Island                   Toxicant
# 7           Whole Island                   Toxicant
# 35          Whole Island                   Toxicant
# 43          Whole Island                   Toxicant
# ...                  ...                        ...
# 1118        Whole Island                   Toxicant
# 1122        Whole Island                   Toxicant
# 1123  Incursion Response                    Unknown
# 1124        Whole Island                   Toxicant
# 1125        Whole Island                   Toxicant
#
#      Secondary Eradication Method Tertiary Eradication Method  \
# 5                        Trapping                         NaN
# 6                             NaN                         NaN
# 7                             NaN                         NaN
# 35                            NaN                         NaN
# 43                            NaN                         NaN
# ...                           ...                         ...
# 1118                          NaN                         NaN
# 1122                          NaN                    Hunting
# 1123                      Unknown                     Unknown
# 1124                          NaN                         NaN
# 1125                          NaN                         NaN
#
#      Primary Baiting Method Secondary Baiting Method Primary Toxicant  \
# 5              Bait Station           Hand Broadcast       Difenacoum
# 6          Aerial Broadcast             Bait Station      Brodifacoum
# 7          Aerial Broadcast             Bait Station      Brodifacoum
# 35             Bait Station                      NaN      Brodifacoum
# 43         Aerial Broadcast                      NaN      Brodifacoum
# ...                     ...                      ...              ...
# 1118         Hand Broadcast                      NaN      Brodifacoum
# 1122                Unknown                  Unknown          Unknown
# 1123                Unknown                  Unknown          Unknown
# 1124           Bait Station                      NaN              NaN
# 1125                Unknown                  Unknown          Unknown
#
#      Secondary Toxicant   Contact Name  \
# 5           Brodifacoum            NaN
# 6                   NaN  Broome; Keith
# 7                   NaN  Broome; Keith
# 35                  NaN   Robinson Sue
# 43                  NaN     Merton; D.
# ...                 ...            ...
# 1118                NaN      Bell; Biz
# 1122            Unknown            NaN
# 1123            Unknown            NaN
# 1124                NaN            NaN
# 1125            Unknown            NaN
#
#                                    Contact Organization  Island Code  \
# 5                                                   NaN      19647.0
# 6                              NZ Dept. of Conservation      26953.0
# 7                              NZ Dept. of Conservation      26953.0
# 35                                       DIPWE Tasmania      26007.0
# 43                             NZ Dept. of Conservation      19644.0
# ...                                                 ...          ...
# 1118  National Trust; RSPB; English Nature; Wildlife...     358145.0
# 1122                                                NaN     242505.0
# 1123                                                NaN     242505.0
# 1124                                                NaN     242194.0
# 1125                                                NaN     242216.0
#
#       Island Name                      Region         Country  \
# 5         Fregate         Indian Ocean - West      Seychelles
# 6      Motutapere  Pacific Ocean - South West     New Zealand
# 7      Motutapere  Pacific Ocean - South West     New Zealand
# 35      Big Green  Pacific Ocean - South West       Australia
# 43       Curieuse         Indian Ocean - West      Seychelles
# ...           ...                         ...             ...
# 1118     Pitcairn  Pacific Ocean - South East        Pitcairn
# 1122         Looe      Atlantic Ocean - North  United Kingdom
# 1123         Looe      Atlantic Ocean - North  United Kingdom
# 1124  Calf of Man      Atlantic Ocean - North  United Kingdom
# 1125       Caldey      Atlantic Ocean - North  United Kingdom
#
#                              Archipelago        Latitude   Longitude  \
# 5                             Seychelles   -4.5854367262   55.941553
# 6                      Coromandel Harbor  -36.7796908943  175.429072
# 7                      Coromandel Harbor  -36.7796908943  175.429072
# 35    Tasmanian Islands (Furneaux Group)  -40.1846423716  147.978612
# 43                            Seychelles  -4.28282941774   55.725510
# ...                                  ...             ...         ...
# 1118                    Pitcairn Islands  -25.0698560232 -130.105789
# 1122                     English Channel   50.3369641713   -4.450453
# 1123                     English Channel   50.3369641713   -4.450453
# 1124                           Irish Sea   54.0534186664   -4.814894
# 1125                     Bristol Channel       51.636918   -4.690882
#
#       Area (sq km) Human Population
# 5         2.001085       101 - 1000
# 6         0.498060         11 - 100
# 7         0.498060         11 - 100
# 35        1.227897           1 - 10
# 43        2.907248           1 - 10
# ...            ...              ...
# 1118      4.040447         11 - 100
# 1122      0.089726           1 - 10
# 1123      0.089726           1 - 10
# 1124      2.464017           1 - 10
# 1125      1.853144         11 - 100
#
# [138 rows x 29 columns]

# %% [markdown]
# As we can see above, there are only 138 rows without 'None' or 'Unknown values'. Since only a small percentage of the rows in the "Human Population" column contain actual data, let's drop this column as well.

# %%
# drop the "Human Population" column
rats = rats.drop('Human Population', axis=1)
rats.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 2         6               8  Brown / Norway Rat  Rattus norvegicus
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 2        Rodent                   NaN          Poor                  1988.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 2                1988.0                 Unknown       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 2                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 2                         NaN                Unknown                      NaN
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 2          Unknown                NaN    Broome; Keith
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
#
#               Contact Organization  Island Code       Island Name  \
# 0                              NaN     242232.0       Ailsa Craig
# 1         NZ Dept. of Conservation      26860.0  Tiritiri Matangi
# 2         NZ Dept. of Conservation      26852.0           Motuihe
# 3  Galapagos National Park Service     362253.0      Marielas Sur
# 4                              NaN     356542.0             Lobos
#
#                        Region         Country        Archipelago  \
# 0      Atlantic Ocean - North  United Kingdom   Scotland Islands
# 1  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 2  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 3  Pacific Ocean - North East         Ecuador  Galapagos Islands
# 4  Pacific Ocean - North East         Ecuador  Galapagos Islands
#
#           Latitude   Longitude  Area (sq km)
# 0    55.2520318774   -5.116668      1.005150
# 1   -36.6008438792  174.890025      2.214972
# 2    -36.812403102  174.946185      1.823291
# 3  -0.599271767236  -91.090560      0.012435
# 4  -0.856468882571  -89.566197      0.073323

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Exploratory data analysis refers to the process of performing investigations on data to discover patterns, spot anomalies, or test hypotheses. Usually this includes creating graphs or running statistical analyses.

# %%
# Here is the rats data set again
rats.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 2         6               8  Brown / Norway Rat  Rattus norvegicus
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 2        Rodent                   NaN          Poor                  1988.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 2                1988.0                 Unknown       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 2                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 2                         NaN                Unknown                      NaN
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 2          Unknown                NaN    Broome; Keith
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
#
#               Contact Organization  Island Code       Island Name  \
# 0                              NaN     242232.0       Ailsa Craig
# 1         NZ Dept. of Conservation      26860.0  Tiritiri Matangi
# 2         NZ Dept. of Conservation      26852.0           Motuihe
# 3  Galapagos National Park Service     362253.0      Marielas Sur
# 4                              NaN     356542.0             Lobos
#
#                        Region         Country        Archipelago  \
# 0      Atlantic Ocean - North  United Kingdom   Scotland Islands
# 1  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 2  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 3  Pacific Ocean - North East         Ecuador  Galapagos Islands
# 4  Pacific Ocean - North East         Ecuador  Galapagos Islands
#
#           Latitude   Longitude  Area (sq km)
# 0    55.2520318774   -5.116668      1.005150
# 1   -36.6008438792  174.890025      2.214972
# 2    -36.812403102  174.946185      1.823291
# 3  -0.599271767236  -91.090560      0.012435
# 4  -0.856468882571  -89.566197      0.073323

# %% [markdown]
# Locate the "Primary Eradication Method" column. This column shows the primary eradication method for each particular eradication. Let's see which method is the most common.

# %%
rats.groupby('Primary Eradication Method')['OBJECTID'].nunique().sort_values(ascending=False)
# Out:
# Primary Eradication Method
# Toxicant    995
# Trapping     79
# Unknown      51
# Hunting       1
# Name: OBJECTID, dtype: int64

# %%
# create a histogram of the primary eradication methods
sns.histplot(data=rats, x='Primary Eradication Method', color='green') #the color parameter allows you to change the color of your graph
plt.title('Number Of Eradications For Each Method') #this adds a title to your graph
# Out:
# Text(0.5, 1.0, 'Number Of Eradications For Each Method')

# %%
# create a histogram of the densities of primary eradication methods for 
# Brown/Norway Rat, Black Rat, House Mouse, and Polynesian Rat 
temp = rats.loc[rats['Common Name'].isin(['Brown / Norway Rat', 'Black Rat', 'House Mouse', 'Polynesian Rat'])]
sns.histplot(data=temp, x='Primary Eradication Method', hue='Common Name', stat='density',multiple='dodge')
plt.title('Densities of Primary Eradication Methods')
# Out:
# Text(0.5, 1.0, 'Densities of Primary Eradication Methods')

# %% [markdown]
# As we can see above, the most popular primary eradication method is toxicant and the least popular is hunting. Now, let's find out which specific toxicant is most popular.

# %%
# Find which primary toxicant is most used
rats.groupby('Primary Toxicant')['OBJECTID'].nunique().sort_values(ascending=False)
# Out:
# Primary Toxicant
# Brodifacoum        703
# Unknown            156
# Diphacinone         84
# Bromadiolone        76
# Warfarin            25
# Pindone             17
# Flocoumafen         11
# Chlorophacinone     11
# Difenacoum           6
# 1080                 5
# Coumatetralyl        3
# Cholecalciferol      3
# Strychnine           1
# Name: OBJECTID, dtype: int64

# %% [markdown]
# Looking above, the second most frequent primary toxicant is "Unknown". Clearly, there is not a toxicant called "unknown", so we can infer that this means there are missing data points, which were replaced with "Unknown". We want to remove these "Unknown" values to get a better picture of the most popular toxicants.

# %%
# clean the "Primary Toxicant" column by removing rows where the Primary Toxicant is "Unknown"
remove_nan = rats[~rats['Primary Toxicant'].isin(['Unknown'])]
remove_nan = remove_nan[remove_nan['Primary Toxicant'].notna()]
remove_nan.head()
# Out:
#    OBJECTID  Eradication ID         Common Name    Scientific Name  \
# 0         2               4  Brown / Norway Rat  Rattus norvegicus
# 1         5               7      Polynesian Rat     Rattus exulans
# 3         8              12           Black Rat      Rattus rattus
# 4         9              13           Black Rat      Rattus rattus
# 5        10              14  Brown / Norway Rat  Rattus norvegicus
#
#   Type (Animal)  Year of Introduction  Data Quality  Eradication Start Date  \
# 0        Rodent                1889.0          Good                  1991.0
# 1        Rodent                   NaN          Good                  1993.0
# 3        Rodent                   NaN  Satisfactory                  2004.0
# 4        Rodent                1600.0  Satisfactory                     NaN
# 5        Rodent                   NaN          Good                  1995.0
#
#    Eradication End Date    Status (Eradication) Type (Eradication)  \
# 0                1992.0              Successful       Whole Island
# 1                1993.0              Successful       Whole Island
# 3                2004.0  Successful (Reinvaded)       Whole Island
# 4                2002.0                  Failed       Whole Island
# 5                1996.0                  Failed       Whole Island
#
#   Primary Eradication Method Secondary Eradication Method  \
# 0                   Toxicant                          NaN
# 1                   Toxicant                          NaN
# 3                   Toxicant                          NaN
# 4                   Toxicant                     Trapping
# 5                   Toxicant                     Trapping
#
#   Tertiary Eradication Method Primary Baiting Method Secondary Baiting Method  \
# 0                         NaN             Bait Piles           Hand Broadcast
# 1                         NaN       Aerial Broadcast             Bait Station
# 3                         NaN           Bait Station                      NaN
# 4                         NaN           Bait Station                      NaN
# 5                         NaN           Bait Station           Hand Broadcast
#
#   Primary Toxicant Secondary Toxicant     Contact Name  \
# 0         Warfarin                NaN              NaN
# 1      Brodifacoum       Bromadiolone     Veitch; C.R.
# 3      Brodifacoum      Coumatetralyl  Carrion; Victor
# 4      Brodifacoum                NaN              NaN
# 5       Difenacoum        Brodifacoum              NaN
#
#               Contact Organization  Island Code       Island Name  \
# 0                              NaN     242232.0       Ailsa Craig
# 1         NZ Dept. of Conservation      26860.0  Tiritiri Matangi
# 3  Galapagos National Park Service     362253.0      Marielas Sur
# 4                              NaN     356542.0             Lobos
# 5                              NaN      19647.0           Fregate
#
#                        Region         Country        Archipelago  \
# 0      Atlantic Ocean - North  United Kingdom   Scotland Islands
# 1  Pacific Ocean - South West     New Zealand       Hauraki Gulf
# 3  Pacific Ocean - North East         Ecuador  Galapagos Islands
# 4  Pacific Ocean - North East         Ecuador  Galapagos Islands
# 5         Indian Ocean - West      Seychelles         Seychelles
#
#           Latitude   Longitude  Area (sq km)
# 0    55.2520318774   -5.116668      1.005150
# 1   -36.6008438792  174.890025      2.214972
# 3  -0.599271767236  -91.090560      0.012435
# 4  -0.856468882571  -89.566197      0.073323
# 5    -4.5854367262   55.941553      2.001085

# %% [markdown]
# Now, let's see the numbers for each toxicant.

# %%
remove_nan.groupby('Primary Toxicant')['OBJECTID'].nunique().sort_values(ascending=False)
# Out:
# Primary Toxicant
# Brodifacoum        703
# Diphacinone         84
# Bromadiolone        76
# Warfarin            25
# Pindone             17
# Flocoumafen         11
# Chlorophacinone     11
# Difenacoum           6
# 1080                 5
# Coumatetralyl        3
# Cholecalciferol      3
# Strychnine           1
# Name: OBJECTID, dtype: int64

# %% [markdown]
# Next, create a horizontal histogram to show the number of primary toxicants used in eradications.

# %%
# To create a hosrizontal histogram, use the 'y=' parameter instead of 'x='
sns.histplot(data=remove_nan, y='Primary Toxicant', color='purple')
plt.title('Primary Toxicant Counts')
# Out:
# Text(0.5, 1.0, 'Primary Toxicant Counts')

# %% [markdown]
# Now, you may be wondering if these eradications are sucessful or not. Luckily, there is a column called "Status (Eradication)", which shows whether or not the eradication was successful.

# %%
# Display the statuses of eradications along with the counts for each
rats.groupby('Status (Eradication)')['OBJECTID'].nunique().sort_values(ascending=False)
# Out:
# Status (Eradication)
# Successful                657
# Successful (Reinvaded)    186
# Failed                    118
# Planned                    36
# To Be Confirmed            33
# Trial or Research only     30
# In Progress                19
# Unknown pre-status         18
# Unknown                    18
# Incomplete                 11
# Name: OBJECTID, dtype: int64

# %% [markdown]
# Looking above, a majority of the eradication attempts are successful. "Successful" means the rodent is no longer present on the island and to our knowledge has not returned. "Successful (Reinvaded)" means the eradication was once successful, but the rodent has returned to the island.

# %% [markdown]
# Next, lets look at the number of eradications over time.

# %% [markdown]
# Create a table that shows each year in the "Eradication End Date" column and the number of eradications per year.

# %%
# Make a table with one column as the eradication end year in ascending order, 
# and another column as the count 
drop_nan_years = rats[rats['Eradication End Date'].notna()]
group_drop_nan_years = drop_nan_years.groupby('Eradication End Date').agg(len).reset_index()

# %%
# Create a line graph showing the number of eradications per year 
sns.lineplot(data=group_drop_nan_years, x='Eradication End Date', y='Common Name', color='red')
plt.ylabel('Number of Eradications')
plt.title('Number Of Eradications Per Year')
# Out:
# Text(0.5, 1.0, 'Number Of Eradications Per Year')

# %% [markdown]
# Now, let's look at the number of eradications over time. Since there are many regions, let's focus on the Caribbean, Mediterranean, Pacific Ocean - South West, and Pacific Ocean - South East. Below, create a line plot with eradication end date on the x-axis and number of eradications on the y-axis. Create overlapping line plots for each region.

# %%
# only look at specific regions listed above
specific_regions = rats[rats['Region'].isin(['Caribbean', 'Mediterranean', 'Pacific Ocean - South West', 'Pacific Ocean - South East'])]

# group by Region and Eradication End Date 
grouped_specific_regions = specific_regions.groupby(['Region', 'Eradication End Date']).agg(len)

sns.lineplot(data=grouped_specific_regions, x='Eradication End Date', y='OBJECTID', hue='Region')

# Label your axes and title your graph 
plt.title('Number Of Eradications Per Year Per Region')
plt.ylabel('Number of Eradications')
# Out:
# Text(0, 0.5, 'Number of Eradications')

# %% [markdown]
# Locations of eradication sites on a map.

# %%
#m = folium.Map(location=[45.5236, -122.6750])

# %% [markdown]
# ## Try it yourself!

# %% [markdown]
# Above, we walked you through analysis on rat eradications from the DIISE dataset. We looked at primary eradication methods and created a visualization to show the number of eradications over time for a few specific regions. Now, it's your turn to do your own exploratory data analysis.

# %% [markdown]
# Go to this link: http://diise.islandconservation.org/ and click "explore". In the search box on the top left, click "...by invasive species" and you'll see a dropdown bar under "Type". Click the dropdown arrow and explore the different types of invasive species. To view the data on each species, click "Run Search".

# %% [markdown]
# Find a species that interests you and that has a good amount of data to work with. We recommend looking at ungulates or mice. When you have chosen the species you want to explore, click the export CSV button on the top bar (on the bar of icons at the top left, it is the fourth from the left).

# %% [markdown]
# Next, you're ready to upload your data to Jupyer notebook! In this part of this assignment, we will provide some starter code. Fill in the missing code wherever you see "...". We will be replicating the analysis we did above, so if you get stuck look at the code we provided for rat eradications above.

# %%
#load the data
... = pd.read_csv("...") # put the file name in the parenthesis
pd.options.display.max_columns = None
....head()
# Out:
#   File "<ipython-input-80-09e8b583eb80>", line 2
#     = pd.read_csv("...") # put the file name in the parenthesis
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Scroll through your data. Do you need to drop any rows or columns? You can drop columns using the .drop() function. If you need help, look at the code we provided above. Drop rows by isolating the rows you want to keep. Again, we've provided code to do this above.

# %%
# Drop any rows or columns here
# Feel free to add more cells as needed. To add a cell, click the plus sign button on the top of this page.

# %% [markdown]
# Now, perform your own exploratory data analysis. First, let's look at the primary eradication methods for your species.

# %%
# show the primary eradication methods and the counts for each
....groupby('Primary Eradication Method')['OBJECTID'].nunique().sort_values(ascending=False)

# %%
# create a histogram of the primary eradication methods
sns.histplot(data=..., x='Primary Eradication Method', color='...') 
plt.title('...')

# %% [markdown]
# Next, let's look at the status of eradications for your species of choice.

# %%
# Display the statuses of eradications along with the counts for each
....groupby('Status (Eradication)')['OBJECTID'].nunique().sort_values(ascending=False)

# %% [markdown]
# Does anything about the data stand out to you?

# %% [markdown]
# Type your answer here.

# %% [markdown]
# Lastly, let's look at the number of eradications over time for your species.

# %%
# Make a table with one column as the eradication end year in ascending order, 
# and another column as the count 
drop_nan_years2 = ...[...['Eradication End Date'].notna()]
group_drop_nan_years2 = drop_nan_years2.groupby('Eradication End Date').agg(len).reset_index()

# %%
# Create a line graph showing the number of eradications per year 
sns....(data=group_drop_nan_years2, x='...', y='Common Name', color='...')
plt.ylabel('...')
plt.title('...')

# %% [markdown]
# Now, let's look at eradication counts over time for a few specific regions. You can choose which regions you want to look at.

# %%
# choose specific regions 
specific_regions2 = ...[...['Region'].isin(['...', '...', '...', '...'])]

# group by Region and Eradication End Date 
grouped_specific_regions2 = specific_regions2.groupby(['...', '...']).agg(len)

sns....(data=grouped_specific_regions2, x='...', y='OBJECTID', hue='Region')

# Label your axes and title your graph 
plt.title('...')
plt.ylabel('...')
